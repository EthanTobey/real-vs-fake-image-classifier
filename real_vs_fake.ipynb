# %%
import os
import zipfile
import pandas as pd
from PIL import Image
from io import BytesIO
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, random_split
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import roc_auc_score, accuracy_score

# --- Load CSV and ZIP ---
df = pd.read_csv('train.csv')
train_dir = 'train/train'

class ImageFolderDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None):
        self.dataframe = dataframe.reset_index(drop=True)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = self.dataframe.iloc[idx, 0]
        label = self.dataframe.iloc[idx, 1]
        img_path = os.path.join(self.root_dir, img_name)
        image = Image.open(img_path).convert('L')
        if self.transform:
            image = self.transform(image)
        return image, label

#Preprocessing - resize all images to 32x32 & convert into pytorch tensor (this normalizes to [0,1] range)
# transform = transforms.Compose([
#     transforms.Resize((32, 32)),
#     transforms.ToTensor()
# ])

#let's try a more encompassing transform
transform = transforms.Compose([
    transforms.Resize((128, 128)),   #larger image to capture more details (likely increase compute time)
    #randomize orientations to increase generalizability
    transforms.RandomHorizontalFlip(),  
    transforms.RandomRotation(10),
    transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),

    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])  # Normalize to [-1, 1]
])


full_dataset = ImageFolderDataset(df, train_dir, transform)

#split into 50% training and 50% validation
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

#loads training and validation data into batches of 128
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)


class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.conv3 = nn.Conv2d(16, 32, 3)
        self.pool = nn.MaxPool2d(2, 2)

        # Dummy input to get the flattened size
        self._to_linear = None
        self._get_flatten_size()

        self.fc1 = nn.Linear(self._to_linear, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 1)

    def _get_flatten_size(self):
        with torch.no_grad():
            x = torch.zeros(1, 1, 128, 128)
            x = self.pool(torch.relu(self.conv1(x)))
            x = self.pool(torch.relu(self.conv2(x)))
            x = torch.relu(self.conv3(x))
            self._to_linear = x.view(1, -1).shape[1]

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = torch.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(torch.cuda.get_device_name(0))
print(device)

#define model w/ class from above
model = LeNet().to(device)
criterion = nn.BCEWithLogitsLoss()  #this function should be better for our task? #nn.CrossEntropyLoss()   #loss function  
optimizer = optim.Adam(model.parameters(), lr=0.001)    #adam learning rate optimizer

#training loop
for epoch in range(10):  #10 epochs
    model.train()
    running_loss = 0.0
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)  #move data to GPU

        optimizer.zero_grad()   #clear previous gradients
        outputs = model(images).squeeze(1)   #compute forward pass
        loss = criterion(outputs, labels.float())    #compute loss
        loss.backward()             #compute back propagation
        optimizer.step()            #update model params

        running_loss += loss.item()

        if (i + 1) % 10 == 0 or (i + 1) == len(train_loader):
            print(f"Epoch [{epoch+1}], Batch [{i+1}/{len(train_loader)}], Batch Loss: {loss.item():.4f}")


    # --- Validation ---
    all_probs, all_labels, all_preds = [], [], []
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)

            # Use sigmoid instead of softmax
            probs = torch.sigmoid(outputs).squeeze(1)
            preds = (probs > 0.5).long()

            all_probs.extend(probs.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

    val_auc = roc_auc_score(all_labels, all_probs)
    val_acc = accuracy_score(all_labels, all_preds)

    print(f"Epoch {epoch+1}, Loss: {running_loss/len(train_loader):.4f}, Val Acc: {val_acc*100:.2f}%, AUC: {val_auc:.4f}")

print("Training + Validation done.")



#now test and save outputs

# --- Predict on Test Set and Save Submission ---
print("Generating test predictions...")

# Test setup
test_dir = 'test/test'
test_filenames = sorted(os.listdir(test_dir))

class TestDataset(Dataset):
    def __init__(self, file_list, root_dir, transform=None):
        self.file_list = file_list
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        img_name = self.file_list[idx]
        img_path = os.path.join(self.root_dir, img_name)
        image = Image.open(img_path).convert('L')
        if self.transform:
            image = self.transform(image)
        return image, img_name

test_dataset = TestDataset(test_filenames, test_dir, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)

# Prediction loop
model.eval()
results = []
with torch.no_grad():
    for images, names in test_loader:
        images = images.to(device)
        outputs = model(images)
        probs = torch.sigmoid(outputs).squeeze(1).cpu().numpy()
        results.extend(zip(names, probs))

# Save to CSV
submission_df = pd.DataFrame(results, columns=["Id", "label"])
submission_df.to_csv("outputs.csv", index=False)
print("Submission file saved as 'outputs.csv'")
# Out:
# NVIDIA GeForce GTX 1080 Ti
# cuda
# Epoch [1], Batch [10/400], Batch Loss: 0.6262
# Epoch [1], Batch [20/400], Batch Loss: 0.5528
# Epoch [1], Batch [30/400], Batch Loss: 0.5103
# Epoch [1], Batch [40/400], Batch Loss: 0.4959
# Epoch [1], Batch [50/400], Batch Loss: 0.4841
# Epoch [1], Batch [60/400], Batch Loss: 0.4107
# Epoch [1], Batch [70/400], Batch Loss: 0.4747
# Epoch [1], Batch [80/400], Batch Loss: 0.4119
# Epoch [1], Batch [90/400], Batch Loss: 0.3828
# Epoch [1], Batch [100/400], Batch Loss: 0.3636
# Epoch [1], Batch [110/400], Batch Loss: 0.5080
# Epoch [1], Batch [120/400], Batch Loss: 0.6495
# Epoch [1], Batch [130/400], Batch Loss: 0.4662
# Epoch [1], Batch [140/400], Batch Loss: 0.4434
# Epoch [1], Batch [150/400], Batch Loss: 0.4582
# Epoch [1], Batch [160/400], Batch Loss: 0.4985
# Epoch [1], Batch [170/400], Batch Loss: 0.4265
# Epoch [1], Batch [180/400], Batch Loss: 0.4457
# Epoch [1], Batch [190/400], Batch Loss: 0.4434
# Epoch [1], Batch [200/400], Batch Loss: 0.3470
# Epoch [1], Batch [210/400], Batch Loss: 0.3826
# Epoch [1], Batch [220/400], Batch Loss: 0.4195
# Epoch [1], Batch [230/400], Batch Loss: 0.4097
# Epoch [1], Batch [240/400], Batch Loss: 0.4064
# Epoch [1], Batch [250/400], Batch Loss: 0.4688
# Epoch [1], Batch [260/400], Batch Loss: 0.4837
# Epoch [1], Batch [270/400], Batch Loss: 0.4184
# Epoch [1], Batch [280/400], Batch Loss: 0.4033
# Epoch [1], Batch [290/400], Batch Loss: 0.4031
# Epoch [1], Batch [300/400], Batch Loss: 0.4360
# Epoch [1], Batch [310/400], Batch Loss: 0.3734
# Epoch [1], Batch [320/400], Batch Loss: 0.4763
# Epoch [1], Batch [330/400], Batch Loss: 0.3957
# Epoch [1], Batch [340/400], Batch Loss: 0.4062
# Epoch [1], Batch [350/400], Batch Loss: 0.4094
# Epoch [1], Batch [360/400], Batch Loss: 0.3863
# Epoch [1], Batch [370/400], Batch Loss: 0.4345
# Epoch [1], Batch [380/400], Batch Loss: 0.4575
# Epoch [1], Batch [390/400], Batch Loss: 0.4023
# Epoch [1], Batch [400/400], Batch Loss: 0.5073
# Epoch 1, Loss: 0.4359, Val Acc: 82.33%, AUC: 0.9039
# Epoch [2], Batch [10/400], Batch Loss: 0.3691
# Epoch [2], Batch [20/400], Batch Loss: 0.4868
# Epoch [2], Batch [30/400], Batch Loss: 0.5134
# Epoch [2], Batch [40/400], Batch Loss: 0.4442
# Epoch [2], Batch [50/400], Batch Loss: 0.3534
# Epoch [2], Batch [60/400], Batch Loss: 0.4426
# Epoch [2], Batch [70/400], Batch Loss: 0.3550
# Epoch [2], Batch [80/400], Batch Loss: 0.3310
# Epoch [2], Batch [90/400], Batch Loss: 0.4090
# Epoch [2], Batch [100/400], Batch Loss: 0.3598
# Epoch [2], Batch [110/400], Batch Loss: 0.4087
# Epoch [2], Batch [120/400], Batch Loss: 0.3406
# Epoch [2], Batch [130/400], Batch Loss: 0.4222
# Epoch [2], Batch [140/400], Batch Loss: 0.4188
# Epoch [2], Batch [150/400], Batch Loss: 0.4140
# Epoch [2], Batch [160/400], Batch Loss: 0.3663
# Epoch [2], Batch [170/400], Batch Loss: 0.4924
# Epoch [2], Batch [180/400], Batch Loss: 0.4115
# Epoch [2], Batch [190/400], Batch Loss: 0.4131
# Epoch [2], Batch [200/400], Batch Loss: 0.4593
# Epoch [2], Batch [210/400], Batch Loss: 0.4560
# Epoch [2], Batch [220/400], Batch Loss: 0.3917
# Epoch [2], Batch [230/400], Batch Loss: 0.4000
# Epoch [2], Batch [240/400], Batch Loss: 0.3802
# Epoch [2], Batch [250/400], Batch Loss: 0.4283
# Epoch [2], Batch [260/400], Batch Loss: 0.3285
# Epoch [2], Batch [270/400], Batch Loss: 0.3886
# Epoch [2], Batch [280/400], Batch Loss: 0.3612
# Epoch [2], Batch [290/400], Batch Loss: 0.3240
# Epoch [2], Batch [300/400], Batch Loss: 0.4609
# Epoch [2], Batch [310/400], Batch Loss: 0.3602
# Epoch [2], Batch [320/400], Batch Loss: 0.3499
# Epoch [2], Batch [330/400], Batch Loss: 0.4678
# Epoch [2], Batch [340/400], Batch Loss: 0.4173
# Epoch [2], Batch [350/400], Batch Loss: 0.3245
# Epoch [2], Batch [360/400], Batch Loss: 0.4386
# Epoch [2], Batch [370/400], Batch Loss: 0.3964
# Epoch [2], Batch [380/400], Batch Loss: 0.3982
# Epoch [2], Batch [390/400], Batch Loss: 0.3151
# Epoch [2], Batch [400/400], Batch Loss: 0.3754
# Epoch 2, Loss: 0.3815, Val Acc: 83.53%, AUC: 0.9126
# Epoch [3], Batch [10/400], Batch Loss: 0.3894
# Epoch [3], Batch [20/400], Batch Loss: 0.3774
# Epoch [3], Batch [30/400], Batch Loss: 0.3972
# Epoch [3], Batch [40/400], Batch Loss: 0.4534
# Epoch [3], Batch [50/400], Batch Loss: 0.3510
# Epoch [3], Batch [60/400], Batch Loss: 0.4362
# Epoch [3], Batch [70/400], Batch Loss: 0.3406
# Epoch [3], Batch [80/400], Batch Loss: 0.4551
# Epoch [3], Batch [90/400], Batch Loss: 0.4134
# Epoch [3], Batch [100/400], Batch Loss: 0.3251
# Epoch [3], Batch [110/400], Batch Loss: 0.3755
# Epoch [3], Batch [120/400], Batch Loss: 0.4189
# Epoch [3], Batch [130/400], Batch Loss: 0.2604
# Epoch [3], Batch [140/400], Batch Loss: 0.4920
# Epoch [3], Batch [150/400], Batch Loss: 0.3489
# Epoch [3], Batch [160/400], Batch Loss: 0.3634
# Epoch [3], Batch [170/400], Batch Loss: 0.2713
# Epoch [3], Batch [180/400], Batch Loss: 0.3635
# Epoch [3], Batch [190/400], Batch Loss: 0.3878
# Epoch [3], Batch [200/400], Batch Loss: 0.3775
# Epoch [3], Batch [210/400], Batch Loss: 0.3243
# Epoch [3], Batch [220/400], Batch Loss: 0.3447
# Epoch [3], Batch [230/400], Batch Loss: 0.4136
# Epoch [3], Batch [240/400], Batch Loss: 0.3170
# Epoch [3], Batch [250/400], Batch Loss: 0.3412
# Epoch [3], Batch [260/400], Batch Loss: 0.3344
# Epoch [3], Batch [270/400], Batch Loss: 0.3625
# Epoch [3], Batch [280/400], Batch Loss: 0.3470
# Epoch [3], Batch [290/400], Batch Loss: 0.4161
# Epoch [3], Batch [300/400], Batch Loss: 0.4695
# Epoch [3], Batch [310/400], Batch Loss: 0.3925
# Epoch [3], Batch [320/400], Batch Loss: 0.2943
# Epoch [3], Batch [330/400], Batch Loss: 0.3648
# Epoch [3], Batch [340/400], Batch Loss: 0.3630
# Epoch [3], Batch [350/400], Batch Loss: 0.3440
# Epoch [3], Batch [360/400], Batch Loss: 0.3852
# Epoch [3], Batch [370/400], Batch Loss: 0.4055
# Epoch [3], Batch [380/400], Batch Loss: 0.3828
# Epoch [3], Batch [390/400], Batch Loss: 0.4437
# Epoch [3], Batch [400/400], Batch Loss: 0.2604
# Epoch 3, Loss: 0.3637, Val Acc: 84.39%, AUC: 0.9237
# Epoch [4], Batch [10/400], Batch Loss: 0.3682
# Epoch [4], Batch [20/400], Batch Loss: 0.2907
# Epoch [4], Batch [30/400], Batch Loss: 0.3669
# Epoch [4], Batch [40/400], Batch Loss: 0.3229
# Epoch [4], Batch [50/400], Batch Loss: 0.3104
# Epoch [4], Batch [60/400], Batch Loss: 0.3571
# Epoch [4], Batch [70/400], Batch Loss: 0.3690
# Epoch [4], Batch [80/400], Batch Loss: 0.3775
# Epoch [4], Batch [90/400], Batch Loss: 0.3550
# Epoch [4], Batch [100/400], Batch Loss: 0.3816
# Epoch [4], Batch [110/400], Batch Loss: 0.2163
# Epoch [4], Batch [120/400], Batch Loss: 0.3934
# Epoch [4], Batch [130/400], Batch Loss: 0.3302
# Epoch [4], Batch [140/400], Batch Loss: 0.2487
# Epoch [4], Batch [150/400], Batch Loss: 0.2877
# Epoch [4], Batch [160/400], Batch Loss: 0.3353
# Epoch [4], Batch [170/400], Batch Loss: 0.3631
# Epoch [4], Batch [180/400], Batch Loss: 0.2862
# Epoch [4], Batch [190/400], Batch Loss: 0.3304
# Epoch [4], Batch [200/400], Batch Loss: 0.3895
# Epoch [4], Batch [210/400], Batch Loss: 0.4065
# Epoch [4], Batch [220/400], Batch Loss: 0.3789
# Epoch [4], Batch [230/400], Batch Loss: 0.3963
# Epoch [4], Batch [240/400], Batch Loss: 0.3937
# Epoch [4], Batch [250/400], Batch Loss: 0.3323
# Epoch [4], Batch [260/400], Batch Loss: 0.3355
# Epoch [4], Batch [270/400], Batch Loss: 0.3057
# Epoch [4], Batch [280/400], Batch Loss: 0.2792
# Epoch [4], Batch [290/400], Batch Loss: 0.2823
# Epoch [4], Batch [300/400], Batch Loss: 0.3318
# Epoch [4], Batch [310/400], Batch Loss: 0.3487
# Epoch [4], Batch [320/400], Batch Loss: 0.3085
# Epoch [4], Batch [330/400], Batch Loss: 0.4808
# Epoch [4], Batch [340/400], Batch Loss: 0.3590
# Epoch [4], Batch [350/400], Batch Loss: 0.3380
# Epoch [4], Batch [360/400], Batch Loss: 0.3527
# Epoch [4], Batch [370/400], Batch Loss: 0.3715
# Epoch [4], Batch [380/400], Batch Loss: 0.2999
# Epoch [4], Batch [390/400], Batch Loss: 0.4204
# Epoch [4], Batch [400/400], Batch Loss: 0.3084
# Epoch 4, Loss: 0.3512, Val Acc: 85.18%, AUC: 0.9259
# Epoch [5], Batch [10/400], Batch Loss: 0.3774
# Epoch [5], Batch [20/400], Batch Loss: 0.3588
# Epoch [5], Batch [30/400], Batch Loss: 0.4013
# Epoch [5], Batch [40/400], Batch Loss: 0.3661
# Epoch [5], Batch [50/400], Batch Loss: 0.3231
# Epoch [5], Batch [60/400], Batch Loss: 0.3473
# Epoch [5], Batch [70/400], Batch Loss: 0.3420
# Epoch [5], Batch [80/400], Batch Loss: 0.2655
# Epoch [5], Batch [90/400], Batch Loss: 0.3333
# Epoch [5], Batch [100/400], Batch Loss: 0.2946
# Epoch [5], Batch [110/400], Batch Loss: 0.2576
# Epoch [5], Batch [120/400], Batch Loss: 0.3231
# Epoch [5], Batch [130/400], Batch Loss: 0.3394
# Epoch [5], Batch [140/400], Batch Loss: 0.3619
# Epoch [5], Batch [150/400], Batch Loss: 0.3207
# Epoch [5], Batch [160/400], Batch Loss: 0.4033
# Epoch [5], Batch [170/400], Batch Loss: 0.2950
# Epoch [5], Batch [180/400], Batch Loss: 0.4050
# Epoch [5], Batch [190/400], Batch Loss: 0.4116
# Epoch [5], Batch [200/400], Batch Loss: 0.4741
# Epoch [5], Batch [210/400], Batch Loss: 0.3573
# Epoch [5], Batch [220/400], Batch Loss: 0.2665
# Epoch [5], Batch [230/400], Batch Loss: 0.4077
# Epoch [5], Batch [240/400], Batch Loss: 0.2856
# Epoch [5], Batch [250/400], Batch Loss: 0.3544
# Epoch [5], Batch [260/400], Batch Loss: 0.3686
# Epoch [5], Batch [270/400], Batch Loss: 0.3827
# Epoch [5], Batch [280/400], Batch Loss: 0.3950
# Epoch [5], Batch [290/400], Batch Loss: 0.2957
# Epoch [5], Batch [300/400], Batch Loss: 0.4170
# Epoch [5], Batch [310/400], Batch Loss: 0.3629
# Epoch [5], Batch [320/400], Batch Loss: 0.4016
# Epoch [5], Batch [330/400], Batch Loss: 0.4200
# Epoch [5], Batch [340/400], Batch Loss: 0.2165
# Epoch [5], Batch [350/400], Batch Loss: 0.3102
# Epoch [5], Batch [360/400], Batch Loss: 0.3854
# Epoch [5], Batch [370/400], Batch Loss: 0.2805
# Epoch [5], Batch [380/400], Batch Loss: 0.3768
# Epoch [5], Batch [390/400], Batch Loss: 0.2438
# Epoch [5], Batch [400/400], Batch Loss: 0.3657
# Epoch 5, Loss: 0.3370, Val Acc: 84.54%, AUC: 0.9305
# Epoch [6], Batch [10/400], Batch Loss: 0.2972
# Epoch [6], Batch [20/400], Batch Loss: 0.4032
# Epoch [6], Batch [30/400], Batch Loss: 0.3679
# Epoch [6], Batch [40/400], Batch Loss: 0.2448
# Epoch [6], Batch [50/400], Batch Loss: 0.3612
# Epoch [6], Batch [60/400], Batch Loss: 0.4607
# Epoch [6], Batch [70/400], Batch Loss: 0.3525
# Epoch [6], Batch [80/400], Batch Loss: 0.3660
# Epoch [6], Batch [90/400], Batch Loss: 0.2722
# Epoch [6], Batch [100/400], Batch Loss: 0.2376
# Epoch [6], Batch [110/400], Batch Loss: 0.3590
# Epoch [6], Batch [120/400], Batch Loss: 0.2263
# Epoch [6], Batch [130/400], Batch Loss: 0.3044
# Epoch [6], Batch [140/400], Batch Loss: 0.3579
# Epoch [6], Batch [150/400], Batch Loss: 0.3096
# Epoch [6], Batch [160/400], Batch Loss: 0.3397
# Epoch [6], Batch [170/400], Batch Loss: 0.3061
# Epoch [6], Batch [180/400], Batch Loss: 0.3051
# Epoch [6], Batch [190/400], Batch Loss: 0.3310
# Epoch [6], Batch [200/400], Batch Loss: 0.3081
# Epoch [6], Batch [210/400], Batch Loss: 0.3537
# Epoch [6], Batch [220/400], Batch Loss: 0.4439
# Epoch [6], Batch [230/400], Batch Loss: 0.3938
# Epoch [6], Batch [240/400], Batch Loss: 0.2911
# Epoch [6], Batch [250/400], Batch Loss: 0.3293
# Epoch [6], Batch [260/400], Batch Loss: 0.2953
# Epoch [6], Batch [270/400], Batch Loss: 0.2741
# Epoch [6], Batch [280/400], Batch Loss: 0.3476
# Epoch [6], Batch [290/400], Batch Loss: 0.4139
# Epoch [6], Batch [300/400], Batch Loss: 0.3181
# Epoch [6], Batch [310/400], Batch Loss: 0.3627
# Epoch [6], Batch [320/400], Batch Loss: 0.2617
# Epoch [6], Batch [330/400], Batch Loss: 0.2594
# Epoch [6], Batch [340/400], Batch Loss: 0.2948
# Epoch [6], Batch [350/400], Batch Loss: 0.3447
# Epoch [6], Batch [360/400], Batch Loss: 0.3534
# Epoch [6], Batch [370/400], Batch Loss: 0.3905
# Epoch [6], Batch [380/400], Batch Loss: 0.3619
# Epoch [6], Batch [390/400], Batch Loss: 0.3219
# Epoch [6], Batch [400/400], Batch Loss: 0.2709
# Epoch 6, Loss: 0.3277, Val Acc: 86.52%, AUC: 0.9375
# Epoch [7], Batch [10/400], Batch Loss: 0.3295
# Epoch [7], Batch [20/400], Batch Loss: 0.3280
# Epoch [7], Batch [30/400], Batch Loss: 0.4087
# Epoch [7], Batch [40/400], Batch Loss: 0.3655
# Epoch [7], Batch [50/400], Batch Loss: 0.2980
# Epoch [7], Batch [60/400], Batch Loss: 0.2927
# Epoch [7], Batch [70/400], Batch Loss: 0.3432
# Epoch [7], Batch [80/400], Batch Loss: 0.3406
# Epoch [7], Batch [90/400], Batch Loss: 0.3404
# Epoch [7], Batch [100/400], Batch Loss: 0.4066
# Epoch [7], Batch [110/400], Batch Loss: 0.2659
# Epoch [7], Batch [120/400], Batch Loss: 0.3248
# Epoch [7], Batch [130/400], Batch Loss: 0.3469
# Epoch [7], Batch [140/400], Batch Loss: 0.3079
# Epoch [7], Batch [150/400], Batch Loss: 0.2916
# Epoch [7], Batch [160/400], Batch Loss: 0.3263
# Epoch [7], Batch [170/400], Batch Loss: 0.3895
# Epoch [7], Batch [180/400], Batch Loss: 0.2675
# Epoch [7], Batch [190/400], Batch Loss: 0.3010
# Epoch [7], Batch [200/400], Batch Loss: 0.2688
# Epoch [7], Batch [210/400], Batch Loss: 0.2758
# Epoch [7], Batch [220/400], Batch Loss: 0.2577
# Epoch [7], Batch [230/400], Batch Loss: 0.2344
# Epoch [7], Batch [240/400], Batch Loss: 0.3197
# Epoch [7], Batch [250/400], Batch Loss: 0.3281
# Epoch [7], Batch [260/400], Batch Loss: 0.3176
# Epoch [7], Batch [270/400], Batch Loss: 0.3650
# Epoch [7], Batch [280/400], Batch Loss: 0.3681
# Epoch [7], Batch [290/400], Batch Loss: 0.2915
# Epoch [7], Batch [300/400], Batch Loss: 0.2366
# Epoch [7], Batch [310/400], Batch Loss: 0.2661
# Epoch [7], Batch [320/400], Batch Loss: 0.4424
# Epoch [7], Batch [330/400], Batch Loss: 0.2730
# Epoch [7], Batch [340/400], Batch Loss: 0.3286
# Epoch [7], Batch [350/400], Batch Loss: 0.2751
# Epoch [7], Batch [360/400], Batch Loss: 0.2659
# Epoch [7], Batch [370/400], Batch Loss: 0.3206
# Epoch [7], Batch [380/400], Batch Loss: 0.3327
# Epoch [7], Batch [390/400], Batch Loss: 0.2677
# Epoch [7], Batch [400/400], Batch Loss: 0.3722
# Epoch 7, Loss: 0.3167, Val Acc: 86.76%, AUC: 0.9408
# Epoch [8], Batch [10/400], Batch Loss: 0.2961
# Epoch [8], Batch [20/400], Batch Loss: 0.3089
# Epoch [8], Batch [30/400], Batch Loss: 0.4126
# Epoch [8], Batch [40/400], Batch Loss: 0.2563
# Epoch [8], Batch [50/400], Batch Loss: 0.4011
# Epoch [8], Batch [60/400], Batch Loss: 0.3244
# Epoch [8], Batch [70/400], Batch Loss: 0.2447
# Epoch [8], Batch [80/400], Batch Loss: 0.3863
# Epoch [8], Batch [90/400], Batch Loss: 0.3863
# Epoch [8], Batch [100/400], Batch Loss: 0.3172
# Epoch [8], Batch [110/400], Batch Loss: 0.2777
# Epoch [8], Batch [120/400], Batch Loss: 0.3292
# Epoch [8], Batch [130/400], Batch Loss: 0.3264
# Epoch [8], Batch [140/400], Batch Loss: 0.4260
# Epoch [8], Batch [150/400], Batch Loss: 0.3114
# Epoch [8], Batch [160/400], Batch Loss: 0.3778
# Epoch [8], Batch [170/400], Batch Loss: 0.2997
# Epoch [8], Batch [180/400], Batch Loss: 0.2442
# Epoch [8], Batch [190/400], Batch Loss: 0.2770
# Epoch [8], Batch [200/400], Batch Loss: 0.3631
# Epoch [8], Batch [210/400], Batch Loss: 0.2891
# Epoch [8], Batch [220/400], Batch Loss: 0.2195
# Epoch [8], Batch [230/400], Batch Loss: 0.2680
# Epoch [8], Batch [240/400], Batch Loss: 0.4280
# Epoch [8], Batch [250/400], Batch Loss: 0.2970
# Epoch [8], Batch [260/400], Batch Loss: 0.2804
# Epoch [8], Batch [270/400], Batch Loss: 0.2812
# Epoch [8], Batch [280/400], Batch Loss: 0.2221
# Epoch [8], Batch [290/400], Batch Loss: 0.2469
# Epoch [8], Batch [300/400], Batch Loss: 0.2824
# Epoch [8], Batch [310/400], Batch Loss: 0.3889
# Epoch [8], Batch [320/400], Batch Loss: 0.2628
# Epoch [8], Batch [330/400], Batch Loss: 0.3120
# Epoch [8], Batch [340/400], Batch Loss: 0.3284
# Epoch [8], Batch [350/400], Batch Loss: 0.2312
# Epoch [8], Batch [360/400], Batch Loss: 0.3073
# Epoch [8], Batch [370/400], Batch Loss: 0.2652
# Epoch [8], Batch [380/400], Batch Loss: 0.2972
# Epoch [8], Batch [390/400], Batch Loss: 0.2635
# Epoch [8], Batch [400/400], Batch Loss: 0.2888
# Epoch 8, Loss: 0.3121, Val Acc: 86.92%, AUC: 0.9404
# Epoch [9], Batch [10/400], Batch Loss: 0.2658
# Epoch [9], Batch [20/400], Batch Loss: 0.2217
# Epoch [9], Batch [30/400], Batch Loss: 0.2264
# Epoch [9], Batch [40/400], Batch Loss: 0.3283
# Epoch [9], Batch [50/400], Batch Loss: 0.3107
# Epoch [9], Batch [60/400], Batch Loss: 0.2487
# Epoch [9], Batch [70/400], Batch Loss: 0.2460
# Epoch [9], Batch [80/400], Batch Loss: 0.3256
# Epoch [9], Batch [90/400], Batch Loss: 0.2184
# Epoch [9], Batch [100/400], Batch Loss: 0.2108
# Epoch [9], Batch [110/400], Batch Loss: 0.3331
# Epoch [9], Batch [120/400], Batch Loss: 0.2818
# Epoch [9], Batch [130/400], Batch Loss: 0.3257
# Epoch [9], Batch [140/400], Batch Loss: 0.3607
# Epoch [9], Batch [150/400], Batch Loss: 0.2989
# Epoch [9], Batch [160/400], Batch Loss: 0.2406
# Epoch [9], Batch [170/400], Batch Loss: 0.3953
# Epoch [9], Batch [180/400], Batch Loss: 0.2743
# Epoch [9], Batch [190/400], Batch Loss: 0.2569
# Epoch [9], Batch [200/400], Batch Loss: 0.2904
# Epoch [9], Batch [210/400], Batch Loss: 0.3847
# Epoch [9], Batch [220/400], Batch Loss: 0.3604
# Epoch [9], Batch [230/400], Batch Loss: 0.2856
# Epoch [9], Batch [240/400], Batch Loss: 0.2740
# Epoch [9], Batch [250/400], Batch Loss: 0.3546
# Epoch [9], Batch [260/400], Batch Loss: 0.4091
# Epoch [9], Batch [270/400], Batch Loss: 0.3542
# Epoch [9], Batch [280/400], Batch Loss: 0.2711
# Epoch [9], Batch [290/400], Batch Loss: 0.2103
# Epoch [9], Batch [300/400], Batch Loss: 0.3191
# Epoch [9], Batch [310/400], Batch Loss: 0.3608
# Epoch [9], Batch [320/400], Batch Loss: 0.3252
# Epoch [9], Batch [330/400], Batch Loss: 0.3048
# Epoch [9], Batch [340/400], Batch Loss: 0.3128
# Epoch [9], Batch [350/400], Batch Loss: 0.4334
# Epoch [9], Batch [360/400], Batch Loss: 0.3202
# Epoch [9], Batch [370/400], Batch Loss: 0.2519
# Epoch [9], Batch [380/400], Batch Loss: 0.3535
# Epoch [9], Batch [390/400], Batch Loss: 0.2765
# Epoch [9], Batch [400/400], Batch Loss: 0.2382
# Epoch 9, Loss: 0.3079, Val Acc: 86.40%, AUC: 0.9430
# Epoch [10], Batch [10/400], Batch Loss: 0.2994
# Epoch [10], Batch [20/400], Batch Loss: 0.2069
# Epoch [10], Batch [30/400], Batch Loss: 0.2467
# Epoch [10], Batch [40/400], Batch Loss: 0.2718
# Epoch [10], Batch [50/400], Batch Loss: 0.2858
# Epoch [10], Batch [60/400], Batch Loss: 0.2562
# Epoch [10], Batch [70/400], Batch Loss: 0.3231
# Epoch [10], Batch [80/400], Batch Loss: 0.2648
# Epoch [10], Batch [90/400], Batch Loss: 0.3258
# Epoch [10], Batch [100/400], Batch Loss: 0.3161
# Epoch [10], Batch [110/400], Batch Loss: 0.3088
# Epoch [10], Batch [120/400], Batch Loss: 0.3091
# Epoch [10], Batch [130/400], Batch Loss: 0.2334
# Epoch [10], Batch [140/400], Batch Loss: 0.2854
# Epoch [10], Batch [150/400], Batch Loss: 0.3115
# Epoch [10], Batch [160/400], Batch Loss: 0.3416
# Epoch [10], Batch [170/400], Batch Loss: 0.3416
# Epoch [10], Batch [180/400], Batch Loss: 0.2942
# Epoch [10], Batch [190/400], Batch Loss: 0.2834
# Epoch [10], Batch [200/400], Batch Loss: 0.3241
# Epoch [10], Batch [210/400], Batch Loss: 0.2719
# Epoch [10], Batch [220/400], Batch Loss: 0.2692
# Epoch [10], Batch [230/400], Batch Loss: 0.2716
# Epoch [10], Batch [240/400], Batch Loss: 0.2874
# Epoch [10], Batch [250/400], Batch Loss: 0.3786
# Epoch [10], Batch [260/400], Batch Loss: 0.2932
# Epoch [10], Batch [270/400], Batch Loss: 0.3286
# Epoch [10], Batch [280/400], Batch Loss: 0.2283
# Epoch [10], Batch [290/400], Batch Loss: 0.2606
# Epoch [10], Batch [300/400], Batch Loss: 0.2487
# Epoch [10], Batch [310/400], Batch Loss: 0.4678
# Epoch [10], Batch [320/400], Batch Loss: 0.2789
# Epoch [10], Batch [330/400], Batch Loss: 0.2317
# Epoch [10], Batch [340/400], Batch Loss: 0.2313
# Epoch [10], Batch [350/400], Batch Loss: 0.2839
# Epoch [10], Batch [360/400], Batch Loss: 0.3174
# Epoch [10], Batch [370/400], Batch Loss: 0.2952
# Epoch [10], Batch [380/400], Batch Loss: 0.4022
# Epoch [10], Batch [390/400], Batch Loss: 0.3780
# Epoch [10], Batch [400/400], Batch Loss: 0.2445
# Epoch 10, Loss: 0.2971, Val Acc: 85.98%, AUC: 0.9445
# Training + Validation done.
# Generating test predictions...
# Submission file saved as 'outputs.csv'

# %%
import os
import zipfile
import numpy as np
import pandas as pd
from PIL import Image
from io import BytesIO
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.linear_model import LogisticRegression
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import roc_auc_score, accuracy_score
from torchvision.models import resnet18, resnet34

# --- Load CSV and ZIP ---
df = pd.read_csv('train.csv')
train_dir = 'train/train'

class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.conv3 = nn.Conv2d(16, 32, 3)
        self.pool = nn.MaxPool2d(2, 2)

        self._to_linear = None
        self._get_flatten_size()

        self.fc1 = nn.Linear(self._to_linear, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 1)

    def _get_flatten_size(self):
        with torch.no_grad():
            x = torch.zeros(1, 1, 128, 128)
            x = self.pool(torch.relu(self.conv1(x)))
            x = self.pool(torch.relu(self.conv2(x)))
            x = torch.relu(self.conv3(x))
            self._to_linear = x.view(1, -1).shape[1]

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = torch.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.net = nn.Sequential(
            nn.Conv2d(1, 16, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(16, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Flatten(),
            nn.Linear(32 * 32 * 32, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )
        
    def forward(self, x):
        return self.net(x)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- Initialize models ---
model1 = LeNet().to(device)
model2 = SimpleCNN().to(device)

models_list = [model1, model2]

class ImageFolderDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None):
        self.dataframe = dataframe.reset_index(drop=True)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = self.dataframe.iloc[idx, 0]
        label = self.dataframe.iloc[idx, 1]
        img_path = os.path.join(self.root_dir, img_name)
        image = Image.open(img_path).convert('L')  # Convert to grayscale
        if self.transform:
            image = self.transform(image)
        return image, label

# --- Define Transforms ---
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

# --- Create Dataset ---
full_dataset = ImageFolderDataset(df, train_dir, transform=transform)

# --- Split into Train and Validation ---
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

# --- Define Dataloaders ---
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)

# --- Training function for a single model ---

def train_model(model, train_loader, val_loader, epochs=5):
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.BCEWithLogitsLoss()

    for epoch in range(epochs):
        model.train()
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images).squeeze(1)
            loss = criterion(outputs, labels.float())
            loss.backward()
            optimizer.step()

# --- Train each model ---
for model in models_list:
    train_model(model, train_loader, val_loader, epochs=5)

print("Base models trained.")

# --- Get validation predictions from each model ---

def get_predictions(model, loader):
    model.eval()
    preds = []
    with torch.no_grad():
        for images, _ in loader:
            images = images.to(device)
            outputs = model(images)
            probs = torch.sigmoid(outputs).squeeze(1)
            preds.append(probs.cpu().numpy())
    return np.concatenate(preds)

val_preds = []
for model in models_list:
    preds = get_predictions(model, val_loader)
    val_preds.append(preds)

val_preds = np.stack(val_preds, axis=1)  # shape: (num_samples, num_models)

# Get true labels
all_labels = []
for _, labels in val_loader:
    all_labels.extend(labels.numpy())
all_labels = np.array(all_labels)

# --- Train Meta Model (Logistic Regression) ---
meta_model = LogisticRegression()
meta_model.fit(val_preds, all_labels)

print("Meta model trained.")

# --- Test Predictions ---

# Get test preds from each model
test_preds = []
for model in models_list:
    preds = []
    for images, names in test_loader:
        images = images.to(device)
        outputs = model(images)
        probs = torch.sigmoid(outputs).squeeze(1)
        preds.append(probs.cpu().numpy())
    preds = np.concatenate(preds)
    test_preds.append(preds)

test_preds = np.stack(test_preds, axis=1)  # shape (num_samples, num_models)

# Use meta model to predict
final_probs = meta_model.predict_proba(test_preds)[:, 1]

# --- Save Final Output ---
submission_df = pd.DataFrame({
    "Id": test_filenames,
    "label": final_probs
})
submission_df.to_csv("stacked_outputs.csv", index=False)

print("Stacked submission saved as 'stacked_outputs.csv'")
# Out:
# Base models trained.
# Meta model trained.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 179
#     177 for model in models_list:
#     178     preds = []
# --> 179     for images, names in test_loader:
#     180         images = images.to(device)
#     181         outputs = model(images)
#
# NameError: name 'test_loader' is not defined

# %% [markdown]
# ### Let's now try one with ResNet, which may take longer to train, but is supposed to perform much better

# %%
import os
import zipfile
import pandas as pd
from PIL import Image
from io import BytesIO
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, random_split
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import roc_auc_score, accuracy_score
from torchvision.models import resnet18, resnet34

# --- Load CSV and ZIP ---
df = pd.read_csv('train.csv')
train_dir = 'train/train'

class ImageFolderDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None):
        self.dataframe = dataframe.reset_index(drop=True)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = self.dataframe.iloc[idx, 0]
        label = self.dataframe.iloc[idx, 1]
        img_path = os.path.join(self.root_dir, img_name)
        image = Image.open(img_path).convert('L')
        if self.transform:
            image = self.transform(image)
        return image, label

#let's try a more encompassing transform
transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
    transforms.RandomCrop(128, padding=4),  # Crop for more variability
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),  # Color jitter
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])


full_dataset = ImageFolderDataset(df, train_dir, transform)

#split into 50% training and 50% validation
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

#loads training and validation data into batches of 128
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)

class CustomResNet(nn.Module):
    def __init__(self):
        super(CustomResNet, self).__init__()
        self.model = resnet34(pretrained=True)   #used to be false

        # Modify first conv layer to accept 1-channel input (instead of 3)
        self.model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)

        # Modify final FC layer to output 1 logit (for binary classification)
        self.model.fc = nn.Linear(self.model.fc.in_features, 1)

    def forward(self, x):
        return self.model(x)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(torch.cuda.get_device_name(0))
print(device)

#define model w/ class from above
model = CustomResNet().to(device)
criterion = nn.BCEWithLogitsLoss()  #this function should be better for our task? #nn.CrossEntropyLoss()   #loss function  
optimizer = optim.Adam(model.parameters(), lr=0.001)    #adam learning rate optimizer

# Add learning rate scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)  # Halve learning rate every 5 epochs

#training loop
for epoch in range(10):  #10 epochs
    model.train()
    running_loss = 0.0
    for i, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)  #move data to GPU

        optimizer.zero_grad()   #clear previous gradients
        outputs = model(images).squeeze(1)   #compute forward pass
        loss = criterion(outputs, labels.float())    #compute loss
        loss.backward()             #compute back propagation
        optimizer.step()            #update model params

        running_loss += loss.item()

        if (i + 1) % 10 == 0 or (i + 1) == len(train_loader):
            print(f"Epoch [{epoch+1}], Batch [{i+1}/{len(train_loader)}], Batch Loss: {loss.item():.4f}")

    # --- Step the scheduler every epoch
    scheduler.step()

    # --- Validation ---
    all_probs, all_labels, all_preds = [], [], []
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)

            # Use sigmoid instead of softmax
            probs = torch.sigmoid(outputs).squeeze(1)
            preds = (probs > 0.5).long()

            all_probs.extend(probs.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

    val_auc = roc_auc_score(all_labels, all_probs)
    val_acc = accuracy_score(all_labels, all_preds)

    print(f"Epoch {epoch+1}, Loss: {running_loss/len(train_loader):.4f}, Val Acc: {val_acc*100:.2f}%, AUC: {val_auc:.4f}")

print("Training + Validation done.")



#now test and save outputs

# --- Predict on Test Set and Save Submission ---
print("Generating test predictions...")

# Test setup
test_dir = 'test/test'
test_filenames = sorted(os.listdir(test_dir))

class TestDataset(Dataset):
    def __init__(self, file_list, root_dir, transform=None):
        self.file_list = file_list
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        img_name = self.file_list[idx]
        img_path = os.path.join(self.root_dir, img_name)
        image = Image.open(img_path).convert('L')
        if self.transform:
            image = self.transform(image)
        return image, img_name

test_dataset = TestDataset(test_filenames, test_dir, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)

# Prediction loop
model.eval()
results = []
with torch.no_grad():
    for images, names in test_loader:
        images = images.to(device)
        outputs = model(images)
        probs = torch.sigmoid(outputs).squeeze(1).cpu().numpy()
        results.extend(zip(names, probs))

# Save to CSV
submission_df = pd.DataFrame(results, columns=["Id", "label"])
submission_df.to_csv("outputs.csv", index=False)
print("Submission file saved as 'outputs.csv'")
# Out:
# NVIDIA GeForce GTX 1080 Ti
# cuda
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to C:\Users\Ethan/.cache\torch\hub\checkpoints\resnet101-63fe2227.pth
# 100.0%
# Epoch [1], Batch [10/800], Batch Loss: 0.4703
# Epoch [1], Batch [20/800], Batch Loss: 0.4543
# Epoch [1], Batch [30/800], Batch Loss: 0.3712
# Epoch [1], Batch [40/800], Batch Loss: 0.4599
# Epoch [1], Batch [50/800], Batch Loss: 0.4753
# Epoch [1], Batch [60/800], Batch Loss: 0.5169
# Epoch [1], Batch [70/800], Batch Loss: 0.2529
# Epoch [1], Batch [80/800], Batch Loss: 0.5297
# Epoch [1], Batch [90/800], Batch Loss: 0.4505
# Epoch [1], Batch [100/800], Batch Loss: 0.3633
# Epoch [1], Batch [110/800], Batch Loss: 0.4084
# Epoch [1], Batch [120/800], Batch Loss: 0.3999
# Epoch [1], Batch [130/800], Batch Loss: 0.3712
# Epoch [1], Batch [140/800], Batch Loss: 0.3561
# Epoch [1], Batch [150/800], Batch Loss: 0.2928
# Epoch [1], Batch [160/800], Batch Loss: 0.2615
# Epoch [1], Batch [170/800], Batch Loss: 0.3975
# Epoch [1], Batch [180/800], Batch Loss: 0.3151
# Epoch [3], Batch [160/800], Batch Loss: 0.2426
# Epoch [3], Batch [170/800], Batch Loss: 0.2744
# Epoch [3], Batch [180/800], Batch Loss: 0.2008
# Epoch [3], Batch [190/800], Batch Loss: 0.3128
# Epoch [3], Batch [200/800], Batch Loss: 0.2574
# Epoch [3], Batch [210/800], Batch Loss: 0.2032
# Epoch [3], Batch [220/800], Batch Loss: 0.3228
# Epoch [3], Batch [230/800], Batch Loss: 0.2394
# Epoch [3], Batch [240/800], Batch Loss: 0.1730
# Epoch [3], Batch [250/800], Batch Loss: 0.2898
# Epoch [3], Batch [260/800], Batch Loss: 0.2881
# Epoch [3], Batch [270/800], Batch Loss: 0.1882
# Epoch [3], Batch [280/800], Batch Loss: 0.1758
# Epoch [3], Batch [290/800], Batch Loss: 0.2549
# Epoch [3], Batch [300/800], Batch Loss: 0.1568
# Epoch [3], Batch [310/800], Batch Loss: 0.1538
# Epoch [3], Batch [320/800], Batch Loss: 0.1694
# Epoch [3], Batch [330/800], Batch Loss: 0.2007
# Epoch [3], Batch [340/800], Batch Loss: 0.4112
# Epoch [3], Batch [350/800], Batch Loss: 0.2544
# Epoch [3], Batch [360/800], Batch Loss: 0.2159
# Epoch [3], Batch [370/800], Batch Loss: 0.3430
# Epoch [3], Batch [380/800], Batch Loss: 0.1414
# Epoch [3], Batch [390/800], Batch Loss: 0.3224
# Epoch [3], Batch [400/800], Batch Loss: 0.3178
# Epoch [3], Batch [410/800], Batch Loss: 0.1872
# Epoch [3], Batch [420/800], Batch Loss: 0.1373
# Epoch [3], Batch [430/800], Batch Loss: 0.3117
# Epoch [3], Batch [440/800], Batch Loss: 0.1922
# Epoch [3], Batch [450/800], Batch Loss: 0.2155
# Epoch [3], Batch [460/800], Batch Loss: 0.3149
# Epoch [3], Batch [470/800], Batch Loss: 0.3150
# Epoch [3], Batch [480/800], Batch Loss: 0.5137
# Epoch [3], Batch [490/800], Batch Loss: 0.3535
# Epoch [3], Batch [500/800], Batch Loss: 0.2220
# Epoch [3], Batch [510/800], Batch Loss: 0.2595
# Epoch [3], Batch [520/800], Batch Loss: 0.2888
# Epoch [3], Batch [530/800], Batch Loss: 0.2010
# Epoch [3], Batch [540/800], Batch Loss: 0.2620
# Epoch [3], Batch [550/800], Batch Loss: 0.2780
# Epoch [3], Batch [560/800], Batch Loss: 0.1731
# Epoch [3], Batch [570/800], Batch Loss: 0.1423
# Epoch [3], Batch [580/800], Batch Loss: 0.4476
# Epoch [3], Batch [590/800], Batch Loss: 0.2385
# Epoch [3], Batch [600/800], Batch Loss: 0.1577
# Epoch [3], Batch [610/800], Batch Loss: 0.2900
# Epoch [3], Batch [620/800], Batch Loss: 0.2905
# Epoch [3], Batch [630/800], Batch Loss: 0.1912
# Epoch [3], Batch [640/800], Batch Loss: 0.2883
# Epoch [3], Batch [650/800], Batch Loss: 0.2924
# Epoch [3], Batch [660/800], Batch Loss: 0.1112
# Epoch [3], Batch [670/800], Batch Loss: 0.2563
# Epoch [3], Batch [680/800], Batch Loss: 0.1941
# Epoch [3], Batch [690/800], Batch Loss: 0.1909
# Epoch [3], Batch [700/800], Batch Loss: 0.2382
# Epoch [3], Batch [710/800], Batch Loss: 0.1871
# Epoch [3], Batch [720/800], Batch Loss: 0.1683
# Epoch [3], Batch [730/800], Batch Loss: 0.2029
# Epoch [3], Batch [740/800], Batch Loss: 0.1842
# Epoch [3], Batch [750/800], Batch Loss: 0.2471
# Epoch [3], Batch [760/800], Batch Loss: 0.2695
# Epoch [3], Batch [770/800], Batch Loss: 0.2027
# Epoch [3], Batch [780/800], Batch Loss: 0.1210
# Epoch [3], Batch [790/800], Batch Loss: 0.3892
# Epoch [3], Batch [800/800], Batch Loss: 0.4052
# Epoch 3, Loss: 0.2527, Val Acc: 89.68%, AUC: 0.9621
# Epoch [4], Batch [10/800], Batch Loss: 0.3855
# Epoch [4], Batch [20/800], Batch Loss: 0.1986
# Epoch [4], Batch [30/800], Batch Loss: 0.2981
# Epoch [4], Batch [40/800], Batch Loss: 0.1986
# Epoch [4], Batch [50/800], Batch Loss: 0.2073
# Epoch [4], Batch [60/800], Batch Loss: 0.2091
# Epoch [4], Batch [70/800], Batch Loss: 0.1993
# Epoch [4], Batch [80/800], Batch Loss: 0.3340
# Epoch [4], Batch [90/800], Batch Loss: 0.1280
# Epoch [4], Batch [100/800], Batch Loss: 0.2167
# Epoch [4], Batch [110/800], Batch Loss: 0.1638
# Epoch [4], Batch [120/800], Batch Loss: 0.1828
# Epoch [4], Batch [130/800], Batch Loss: 0.1547
# Epoch [4], Batch [140/800], Batch Loss: 0.1159
# Epoch [4], Batch [150/800], Batch Loss: 0.2303
# Epoch [4], Batch [160/800], Batch Loss: 0.1637
# Epoch [4], Batch [170/800], Batch Loss: 0.0969
# Epoch [4], Batch [180/800], Batch Loss: 0.1104
# Epoch [4], Batch [190/800], Batch Loss: 0.1132
# Epoch [4], Batch [200/800], Batch Loss: 0.3351
# Epoch [4], Batch [210/800], Batch Loss: 0.2213
# Epoch [4], Batch [220/800], Batch Loss: 0.2572
# Epoch [4], Batch [230/800], Batch Loss: 0.2086
# Epoch [4], Batch [240/800], Batch Loss: 0.3639
# Epoch [4], Batch [250/800], Batch Loss: 0.2191
# Epoch [4], Batch [260/800], Batch Loss: 0.3051
# Epoch [4], Batch [270/800], Batch Loss: 0.2355
# Epoch [4], Batch [280/800], Batch Loss: 0.2826
# Epoch [4], Batch [290/800], Batch Loss: 0.1422
# Epoch [4], Batch [300/800], Batch Loss: 0.2225
# Epoch [4], Batch [310/800], Batch Loss: 0.2851
# Epoch [4], Batch [320/800], Batch Loss: 0.1779
# Epoch [4], Batch [330/800], Batch Loss: 0.2553
# Epoch [4], Batch [340/800], Batch Loss: 0.1805
# Epoch [4], Batch [350/800], Batch Loss: 0.1829
# Epoch [4], Batch [360/800], Batch Loss: 0.2382
# Epoch [4], Batch [370/800], Batch Loss: 0.2625
# Epoch [4], Batch [380/800], Batch Loss: 0.2682
# Epoch [4], Batch [390/800], Batch Loss: 0.3807
# Epoch [4], Batch [400/800], Batch Loss: 0.3718
# Epoch [4], Batch [410/800], Batch Loss: 0.2848
# Epoch [4], Batch [420/800], Batch Loss: 0.2221
# Epoch [4], Batch [430/800], Batch Loss: 0.2703
# Epoch [4], Batch [440/800], Batch Loss: 0.1523
# Epoch [4], Batch [450/800], Batch Loss: 0.2859
# Epoch [4], Batch [460/800], Batch Loss: 0.2490
# Epoch [4], Batch [470/800], Batch Loss: 0.1339
# Epoch [4], Batch [480/800], Batch Loss: 0.1209
# Epoch [4], Batch [490/800], Batch Loss: 0.1188
# Epoch [4], Batch [500/800], Batch Loss: 0.2161
# Epoch [4], Batch [510/800], Batch Loss: 0.2333
# Epoch [4], Batch [520/800], Batch Loss: 0.1309
# Epoch [4], Batch [530/800], Batch Loss: 0.3009
# Epoch [4], Batch [540/800], Batch Loss: 0.2275
# Epoch [4], Batch [550/800], Batch Loss: 0.1409
# Epoch [4], Batch [560/800], Batch Loss: 0.2153
# Epoch [4], Batch [570/800], Batch Loss: 0.1253
# Epoch [4], Batch [580/800], Batch Loss: 0.1003
# Epoch [4], Batch [590/800], Batch Loss: 0.1580
# Epoch [4], Batch [600/800], Batch Loss: 0.1955
# Epoch [4], Batch [610/800], Batch Loss: 0.2913
# Epoch [4], Batch [620/800], Batch Loss: 0.3293
# Epoch [4], Batch [630/800], Batch Loss: 0.1890
# Epoch [4], Batch [640/800], Batch Loss: 0.1603
# Epoch [4], Batch [650/800], Batch Loss: 0.1618
# Epoch [4], Batch [660/800], Batch Loss: 0.1800
# Epoch [4], Batch [670/800], Batch Loss: 0.2722
# Epoch [4], Batch [680/800], Batch Loss: 0.2388
# Epoch [4], Batch [690/800], Batch Loss: 0.2279
# Epoch [4], Batch [700/800], Batch Loss: 0.1204
# Epoch [4], Batch [710/800], Batch Loss: 0.2116
# Epoch [4], Batch [720/800], Batch Loss: 0.1878
# Epoch [4], Batch [730/800], Batch Loss: 0.2342
# Epoch [4], Batch [740/800], Batch Loss: 0.1684
# Epoch [4], Batch [750/800], Batch Loss: 0.1436
# Epoch [4], Batch [760/800], Batch Loss: 0.3330
# Epoch [4], Batch [770/800], Batch Loss: 0.2926
# Epoch [4], Batch [780/800], Batch Loss: 0.2680
# Epoch [4], Batch [790/800], Batch Loss: 0.2140
# Epoch [4], Batch [800/800], Batch Loss: 0.2577
# Epoch 4, Loss: 0.2239, Val Acc: 91.97%, AUC: 0.9749
# Epoch [5], Batch [10/800], Batch Loss: 0.1720
# Epoch [5], Batch [20/800], Batch Loss: 0.2430
# Epoch [5], Batch [30/800], Batch Loss: 0.1775
# Epoch [5], Batch [40/800], Batch Loss: 0.3178
# Epoch [5], Batch [50/800], Batch Loss: 0.2541
# Epoch [5], Batch [60/800], Batch Loss: 0.1408
# Epoch [5], Batch [70/800], Batch Loss: 0.2376
# Epoch [5], Batch [80/800], Batch Loss: 0.2027
# Epoch [5], Batch [90/800], Batch Loss: 0.3094
# Epoch [5], Batch [100/800], Batch Loss: 0.3010
# Epoch [5], Batch [110/800], Batch Loss: 0.1739
# Epoch [5], Batch [120/800], Batch Loss: 0.2260
# Epoch [5], Batch [130/800], Batch Loss: 0.1273
# Epoch [5], Batch [140/800], Batch Loss: 0.2611
# Epoch [5], Batch [150/800], Batch Loss: 0.1904
# Epoch [5], Batch [160/800], Batch Loss: 0.2428
# Epoch [5], Batch [170/800], Batch Loss: 0.1992
# Epoch [5], Batch [180/800], Batch Loss: 0.2226
# Epoch [5], Batch [190/800], Batch Loss: 0.2957
# Epoch [5], Batch [200/800], Batch Loss: 0.2569
# Epoch [5], Batch [210/800], Batch Loss: 0.1040
# Epoch [5], Batch [220/800], Batch Loss: 0.1817
# Epoch [5], Batch [230/800], Batch Loss: 0.1393
# Epoch [5], Batch [240/800], Batch Loss: 0.1478
# Epoch [5], Batch [250/800], Batch Loss: 0.1901
# Epoch [5], Batch [260/800], Batch Loss: 0.1761
# Epoch [5], Batch [270/800], Batch Loss: 0.2717
# Epoch [5], Batch [280/800], Batch Loss: 0.1820
# Epoch [5], Batch [290/800], Batch Loss: 0.1515
# Epoch [5], Batch [300/800], Batch Loss: 0.1750
# Epoch [5], Batch [310/800], Batch Loss: 0.1322
# Epoch [5], Batch [320/800], Batch Loss: 0.1503
# Epoch [5], Batch [330/800], Batch Loss: 0.2626
# Epoch [5], Batch [340/800], Batch Loss: 0.1396
# Epoch [5], Batch [350/800], Batch Loss: 0.1993
# Epoch [5], Batch [360/800], Batch Loss: 0.3758
# Epoch [5], Batch [370/800], Batch Loss: 0.1904
# Epoch [5], Batch [380/800], Batch Loss: 0.2473
# Epoch [5], Batch [390/800], Batch Loss: 0.1523
# Epoch [5], Batch [400/800], Batch Loss: 0.3219
# Epoch [5], Batch [410/800], Batch Loss: 0.1605
# Epoch [5], Batch [420/800], Batch Loss: 0.3283
# Epoch [5], Batch [430/800], Batch Loss: 0.2074
# Epoch [5], Batch [440/800], Batch Loss: 0.0897
# Epoch [5], Batch [450/800], Batch Loss: 0.1981
# Epoch [5], Batch [460/800], Batch Loss: 0.1712
# Epoch [5], Batch [470/800], Batch Loss: 0.2199
# Epoch [5], Batch [480/800], Batch Loss: 0.2893
# Epoch [5], Batch [490/800], Batch Loss: 0.1988
# Epoch [5], Batch [500/800], Batch Loss: 0.2839
# Epoch [5], Batch [510/800], Batch Loss: 0.2350
# Epoch [5], Batch [520/800], Batch Loss: 0.1966
# Epoch [5], Batch [530/800], Batch Loss: 0.1533
# Epoch [5], Batch [540/800], Batch Loss: 0.3000
# Epoch [5], Batch [550/800], Batch Loss: 0.1401
# Epoch [5], Batch [560/800], Batch Loss: 0.1998
# Epoch [5], Batch [570/800], Batch Loss: 0.3067
# Epoch [5], Batch [580/800], Batch Loss: 0.1644
# Epoch [5], Batch [590/800], Batch Loss: 0.2329
# Epoch [5], Batch [600/800], Batch Loss: 0.1896
# Epoch [5], Batch [610/800], Batch Loss: 0.2441
# Epoch [5], Batch [620/800], Batch Loss: 0.1354
# Epoch [5], Batch [630/800], Batch Loss: 0.1456
# Epoch [5], Batch [640/800], Batch Loss: 0.3067
# Epoch [5], Batch [650/800], Batch Loss: 0.1762
# Epoch [7], Batch [90/800], Batch Loss: 0.2350
# Epoch [7], Batch [100/800], Batch Loss: 0.2781
# Epoch [7], Batch [110/800], Batch Loss: 0.1018
# Epoch [7], Batch [120/800], Batch Loss: 0.1251
# Epoch [7], Batch [130/800], Batch Loss: 0.0866
# Epoch [7], Batch [140/800], Batch Loss: 0.0801
# Epoch [7], Batch [150/800], Batch Loss: 0.1185
# Epoch [7], Batch [160/800], Batch Loss: 0.1569
# Epoch [7], Batch [170/800], Batch Loss: 0.2985
# Epoch [7], Batch [180/800], Batch Loss: 0.1650
# Epoch [7], Batch [190/800], Batch Loss: 0.2458
# Epoch [7], Batch [200/800], Batch Loss: 0.3579
# Epoch [7], Batch [210/800], Batch Loss: 0.2053
# Epoch [7], Batch [220/800], Batch Loss: 0.1567
# Epoch [7], Batch [230/800], Batch Loss: 0.2179
# Epoch [7], Batch [240/800], Batch Loss: 0.1282
# Epoch [7], Batch [250/800], Batch Loss: 0.1776
# Epoch [7], Batch [260/800], Batch Loss: 0.1737
# Epoch [7], Batch [270/800], Batch Loss: 0.1566
# Epoch [7], Batch [280/800], Batch Loss: 0.1763
# Epoch [7], Batch [290/800], Batch Loss: 0.1771
# Epoch [7], Batch [300/800], Batch Loss: 0.2498
# Epoch [7], Batch [310/800], Batch Loss: 0.3665
# Epoch [7], Batch [320/800], Batch Loss: 0.0901
# Epoch [7], Batch [330/800], Batch Loss: 0.1339
# Epoch [7], Batch [340/800], Batch Loss: 0.2780
# Epoch [7], Batch [350/800], Batch Loss: 0.2846
# Epoch [7], Batch [360/800], Batch Loss: 0.1517
# Epoch [7], Batch [370/800], Batch Loss: 0.2046
# Epoch [7], Batch [380/800], Batch Loss: 0.1948
# Epoch [7], Batch [390/800], Batch Loss: 0.2464
# Epoch [7], Batch [400/800], Batch Loss: 0.1106
# Epoch [7], Batch [410/800], Batch Loss: 0.1043
# Epoch [7], Batch [420/800], Batch Loss: 0.1135
# Epoch [7], Batch [430/800], Batch Loss: 0.2437
# Epoch [7], Batch [440/800], Batch Loss: 0.0858
# Epoch [7], Batch [450/800], Batch Loss: 0.0963
# Epoch [7], Batch [460/800], Batch Loss: 0.1181
# Epoch [7], Batch [470/800], Batch Loss: 0.1117
# Epoch [7], Batch [480/800], Batch Loss: 0.1570
# Epoch [7], Batch [490/800], Batch Loss: 0.1266
# Epoch [7], Batch [500/800], Batch Loss: 0.1655
# Epoch [7], Batch [510/800], Batch Loss: 0.1412
# Epoch [7], Batch [520/800], Batch Loss: 0.1367
# Epoch [7], Batch [530/800], Batch Loss: 0.1136
# Epoch [7], Batch [540/800], Batch Loss: 0.1171
# Epoch [7], Batch [550/800], Batch Loss: 0.1365
# Epoch [7], Batch [560/800], Batch Loss: 0.1936
# Epoch [7], Batch [570/800], Batch Loss: 0.1418
# Epoch [7], Batch [580/800], Batch Loss: 0.2034
# Epoch [7], Batch [590/800], Batch Loss: 0.1153
# Epoch [7], Batch [600/800], Batch Loss: 0.3164
# Epoch [7], Batch [610/800], Batch Loss: 0.3320
# Epoch [7], Batch [620/800], Batch Loss: 0.1585
# Epoch [7], Batch [630/800], Batch Loss: 0.1071
# Epoch [7], Batch [640/800], Batch Loss: 0.1961
# Epoch [7], Batch [650/800], Batch Loss: 0.3422
# Epoch [7], Batch [660/800], Batch Loss: 0.1546
# Epoch [7], Batch [670/800], Batch Loss: 0.0910
# Epoch [7], Batch [680/800], Batch Loss: 0.0677
# Epoch [7], Batch [690/800], Batch Loss: 0.2451
# Epoch [7], Batch [700/800], Batch Loss: 0.2727
# Epoch [7], Batch [710/800], Batch Loss: 0.1565
# Epoch [7], Batch [720/800], Batch Loss: 0.1597
# Epoch [7], Batch [730/800], Batch Loss: 0.1664
# Epoch [7], Batch [740/800], Batch Loss: 0.1275
# Epoch [7], Batch [750/800], Batch Loss: 0.1344
# Epoch [7], Batch [760/800], Batch Loss: 0.2018
# Epoch [7], Batch [770/800], Batch Loss: 0.2011
# Epoch [7], Batch [780/800], Batch Loss: 0.1351
# Epoch [7], Batch [790/800], Batch Loss: 0.1692
# Epoch [7], Batch [800/800], Batch Loss: 0.3056
# Epoch 7, Loss: 0.1699, Val Acc: 93.52%, AUC: 0.9820
# Epoch [8], Batch [10/800], Batch Loss: 0.1444
# Epoch [8], Batch [20/800], Batch Loss: 0.1520
# Epoch [8], Batch [30/800], Batch Loss: 0.2412
# Epoch [8], Batch [40/800], Batch Loss: 0.1595
# Epoch [8], Batch [50/800], Batch Loss: 0.1577
# Epoch [8], Batch [60/800], Batch Loss: 0.1344
# Epoch [8], Batch [70/800], Batch Loss: 0.2935
# Epoch [8], Batch [80/800], Batch Loss: 0.2418
# Epoch [8], Batch [90/800], Batch Loss: 0.1215
# Epoch [8], Batch [100/800], Batch Loss: 0.0963
# Epoch [8], Batch [110/800], Batch Loss: 0.1105
# Epoch [8], Batch [120/800], Batch Loss: 0.1469
# Epoch [8], Batch [130/800], Batch Loss: 0.1454
# Epoch [8], Batch [140/800], Batch Loss: 0.1149
# Epoch [8], Batch [150/800], Batch Loss: 0.2146
# Epoch [8], Batch [160/800], Batch Loss: 0.0847
# Epoch [8], Batch [170/800], Batch Loss: 0.3040
# Epoch [8], Batch [180/800], Batch Loss: 0.1124
# Epoch [8], Batch [190/800], Batch Loss: 0.1470
# Epoch [8], Batch [200/800], Batch Loss: 0.1368
# Epoch [8], Batch [210/800], Batch Loss: 0.2453
# Epoch [8], Batch [220/800], Batch Loss: 0.2165
# Epoch [8], Batch [230/800], Batch Loss: 0.0894
# Epoch [8], Batch [240/800], Batch Loss: 0.0671
# Epoch [8], Batch [250/800], Batch Loss: 0.0908
# Epoch [8], Batch [260/800], Batch Loss: 0.1091
# Epoch [8], Batch [270/800], Batch Loss: 0.0982
# Epoch [8], Batch [280/800], Batch Loss: 0.1229
# Epoch [8], Batch [290/800], Batch Loss: 0.1421
# Epoch [8], Batch [300/800], Batch Loss: 0.1945
# Epoch [8], Batch [310/800], Batch Loss: 0.1775
# Epoch [8], Batch [320/800], Batch Loss: 0.1592
# Epoch [8], Batch [330/800], Batch Loss: 0.2225
# Epoch [9], Batch [60/800], Batch Loss: 0.0829
# Epoch [9], Batch [70/800], Batch Loss: 0.1016
# Epoch [9], Batch [80/800], Batch Loss: 0.1427
# Epoch [9], Batch [90/800], Batch Loss: 0.1526
# Epoch [9], Batch [100/800], Batch Loss: 0.2572
# Epoch [9], Batch [110/800], Batch Loss: 0.1525
# Epoch [9], Batch [120/800], Batch Loss: 0.1932
# Epoch [9], Batch [130/800], Batch Loss: 0.0975
# Epoch [9], Batch [140/800], Batch Loss: 0.1032
# Epoch [9], Batch [150/800], Batch Loss: 0.1872
# Epoch [9], Batch [160/800], Batch Loss: 0.1574
# Epoch [9], Batch [170/800], Batch Loss: 0.1778
# Epoch [9], Batch [180/800], Batch Loss: 0.1478
# Epoch [9], Batch [190/800], Batch Loss: 0.1481
# Epoch [9], Batch [200/800], Batch Loss: 0.1227
# Epoch [9], Batch [210/800], Batch Loss: 0.1812
# Epoch [9], Batch [220/800], Batch Loss: 0.1901
# Epoch [9], Batch [230/800], Batch Loss: 0.1782
# Epoch [9], Batch [240/800], Batch Loss: 0.1389
# Epoch [9], Batch [250/800], Batch Loss: 0.1118
# Epoch [9], Batch [260/800], Batch Loss: 0.1721
# Epoch [9], Batch [270/800], Batch Loss: 0.1728
# Epoch [9], Batch [280/800], Batch Loss: 0.1519
# Epoch [9], Batch [290/800], Batch Loss: 0.1044
# Epoch [9], Batch [300/800], Batch Loss: 0.1593
# Epoch [9], Batch [310/800], Batch Loss: 0.2146
# Epoch [9], Batch [320/800], Batch Loss: 0.2353
# Epoch [9], Batch [330/800], Batch Loss: 0.0925
# Epoch [9], Batch [340/800], Batch Loss: 0.1210
# Epoch [9], Batch [350/800], Batch Loss: 0.1181
# Epoch [9], Batch [360/800], Batch Loss: 0.2376
# Epoch [9], Batch [370/800], Batch Loss: 0.1071
# Epoch [9], Batch [380/800], Batch Loss: 0.1179
# Epoch [9], Batch [390/800], Batch Loss: 0.1290
# Epoch [9], Batch [400/800], Batch Loss: 0.2522
# Epoch [9], Batch [410/800], Batch Loss: 0.1394
# Epoch [9], Batch [420/800], Batch Loss: 0.1078
# Epoch [9], Batch [430/800], Batch Loss: 0.2329
# Epoch [9], Batch [440/800], Batch Loss: 0.1273
# Epoch [9], Batch [450/800], Batch Loss: 0.1092
# Epoch [9], Batch [460/800], Batch Loss: 0.0462
# Epoch [9], Batch [470/800], Batch Loss: 0.2083
# Epoch [9], Batch [480/800], Batch Loss: 0.1773
# Epoch [9], Batch [490/800], Batch Loss: 0.0781
# Epoch [9], Batch [500/800], Batch Loss: 0.1055
# Epoch [9], Batch [510/800], Batch Loss: 0.1006
# Epoch [9], Batch [520/800], Batch Loss: 0.0544
# Epoch [9], Batch [530/800], Batch Loss: 0.1971
# Epoch [9], Batch [540/800], Batch Loss: 0.0923
# Epoch [9], Batch [550/800], Batch Loss: 0.0941
# Epoch [9], Batch [560/800], Batch Loss: 0.1698
# Epoch [9], Batch [570/800], Batch Loss: 0.1664
# Epoch [9], Batch [580/800], Batch Loss: 0.0756
# Epoch [9], Batch [590/800], Batch Loss: 0.0942
# Epoch [9], Batch [600/800], Batch Loss: 0.2560
# Epoch [9], Batch [610/800], Batch Loss: 0.1161
# Epoch [9], Batch [620/800], Batch Loss: 0.1488
# Epoch [9], Batch [630/800], Batch Loss: 0.1365
# Epoch [9], Batch [640/800], Batch Loss: 0.1177
# Epoch [9], Batch [650/800], Batch Loss: 0.0948
# Epoch [9], Batch [660/800], Batch Loss: 0.0817
# Epoch [9], Batch [670/800], Batch Loss: 0.3030
# Epoch [9], Batch [680/800], Batch Loss: 0.1259
# Epoch [9], Batch [690/800], Batch Loss: 0.2436
# Epoch [9], Batch [700/800], Batch Loss: 0.0792
# Epoch [9], Batch [710/800], Batch Loss: 0.0984
# Epoch [9], Batch [720/800], Batch Loss: 0.1931
# Epoch [9], Batch [730/800], Batch Loss: 0.1724
# Epoch [9], Batch [740/800], Batch Loss: 0.1324
# Epoch [9], Batch [750/800], Batch Loss: 0.2188
# Epoch [9], Batch [760/800], Batch Loss: 0.1593
# Epoch [9], Batch [770/800], Batch Loss: 0.0951
# Epoch [9], Batch [780/800], Batch Loss: 0.1969
# Epoch [9], Batch [790/800], Batch Loss: 0.2010
# Epoch [9], Batch [800/800], Batch Loss: 0.0470
# Epoch 9, Loss: 0.1522, Val Acc: 94.11%, AUC: 0.9847
# Epoch [10], Batch [10/800], Batch Loss: 0.1133
# Epoch [10], Batch [20/800], Batch Loss: 0.1817
# Epoch [10], Batch [30/800], Batch Loss: 0.1429
# Epoch [10], Batch [40/800], Batch Loss: 0.2099
# Epoch [10], Batch [50/800], Batch Loss: 0.1111
# Epoch [10], Batch [60/800], Batch Loss: 0.1137
# Epoch [10], Batch [70/800], Batch Loss: 0.1407
# Epoch [10], Batch [80/800], Batch Loss: 0.1682
# Epoch [10], Batch [90/800], Batch Loss: 0.1023
# Epoch [10], Batch [100/800], Batch Loss: 0.1374
# Epoch [10], Batch [110/800], Batch Loss: 0.1432
# Epoch [10], Batch [120/800], Batch Loss: 0.1130
# Epoch [10], Batch [130/800], Batch Loss: 0.2746
# Epoch [10], Batch [140/800], Batch Loss: 0.1376
# Epoch [10], Batch [150/800], Batch Loss: 0.1658
# Epoch [10], Batch [160/800], Batch Loss: 0.0656
# Epoch [10], Batch [170/800], Batch Loss: 0.0644
# Epoch [10], Batch [180/800], Batch Loss: 0.1312
# Epoch [10], Batch [190/800], Batch Loss: 0.1255
# Epoch [10], Batch [200/800], Batch Loss: 0.1753
# Epoch [10], Batch [210/800], Batch Loss: 0.1122
# Epoch [10], Batch [220/800], Batch Loss: 0.0843
# Epoch [10], Batch [230/800], Batch Loss: 0.1604
# Epoch [10], Batch [240/800], Batch Loss: 0.1111
# Epoch [10], Batch [250/800], Batch Loss: 0.1017
# Epoch [10], Batch [260/800], Batch Loss: 0.1415
# Epoch [10], Batch [270/800], Batch Loss: 0.1022
# Epoch [10], Batch [280/800], Batch Loss: 0.1617
# Epoch [10], Batch [290/800], Batch Loss: 0.1415
# Epoch [10], Batch [300/800], Batch Loss: 0.1382
# Epoch [10], Batch [310/800], Batch Loss: 0.2049
# Epoch [10], Batch [320/800], Batch Loss: 0.1437
# Epoch [10], Batch [330/800], Batch Loss: 0.1150
# Epoch [10], Batch [340/800], Batch Loss: 0.1079
# Epoch [10], Batch [350/800], Batch Loss: 0.0807
# Epoch [10], Batch [360/800], Batch Loss: 0.1390
# Epoch [10], Batch [370/800], Batch Loss: 0.2106
# Epoch [10], Batch [380/800], Batch Loss: 0.1428
# Epoch [10], Batch [390/800], Batch Loss: 0.0544
# Epoch [10], Batch [400/800], Batch Loss: 0.2160
# Epoch [10], Batch [410/800], Batch Loss: 0.1822
# Epoch [10], Batch [420/800], Batch Loss: 0.1467
# Epoch [10], Batch [430/800], Batch Loss: 0.0989
# Epoch [10], Batch [440/800], Batch Loss: 0.1804
# Epoch [10], Batch [450/800], Batch Loss: 0.3134
# Epoch [10], Batch [460/800], Batch Loss: 0.1758
# Epoch [10], Batch [470/800], Batch Loss: 0.1490
# Epoch [10], Batch [480/800], Batch Loss: 0.2337
# Epoch [10], Batch [490/800], Batch Loss: 0.1512
# Epoch [10], Batch [500/800], Batch Loss: 0.0660
# Epoch [10], Batch [510/800], Batch Loss: 0.0833
# Epoch [10], Batch [520/800], Batch Loss: 0.1148
# Epoch [10], Batch [530/800], Batch Loss: 0.1616
# Epoch [10], Batch [540/800], Batch Loss: 0.1511
# Epoch [10], Batch [550/800], Batch Loss: 0.2406
# Epoch [10], Batch [560/800], Batch Loss: 0.1379
# Epoch [10], Batch [570/800], Batch Loss: 0.0959
# Epoch [10], Batch [580/800], Batch Loss: 0.1211
# Epoch [10], Batch [590/800], Batch Loss: 0.1354
# Epoch [10], Batch [600/800], Batch Loss: 0.1191
# Epoch [10], Batch [610/800], Batch Loss: 0.1603
# Epoch [10], Batch [620/800], Batch Loss: 0.0894
# Epoch [10], Batch [630/800], Batch Loss: 0.0982
# Epoch [10], Batch [640/800], Batch Loss: 0.1657
# Epoch [10], Batch [650/800], Batch Loss: 0.1861
# Epoch [10], Batch [660/800], Batch Loss: 0.2370
# Epoch [10], Batch [670/800], Batch Loss: 0.1284
# Epoch [10], Batch [680/800], Batch Loss: 0.2874
# Epoch [10], Batch [690/800], Batch Loss: 0.1596
# Epoch [10], Batch [700/800], Batch Loss: 0.0861
# Epoch [10], Batch [710/800], Batch Loss: 0.1639
# Epoch [10], Batch [720/800], Batch Loss: 0.1495
# Epoch [10], Batch [730/800], Batch Loss: 0.1808
# Epoch [10], Batch [740/800], Batch Loss: 0.2436
# Epoch [10], Batch [750/800], Batch Loss: 0.1824
# Epoch [10], Batch [760/800], Batch Loss: 0.0818
# Epoch [10], Batch [770/800], Batch Loss: 0.1932
# Epoch [10], Batch [780/800], Batch Loss: 0.0617
# Epoch [10], Batch [790/800], Batch Loss: 0.1685
# Epoch [10], Batch [800/800], Batch Loss: 0.1229
# Epoch 10, Loss: 0.1471, Val Acc: 94.57%, AUC: 0.9870
# Training + Validation done.
# Generating test predictions...
# Submission file saved as 'outputs.csv'
